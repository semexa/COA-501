# %% [markdown]
# # EVALUACIÓN DEL DAÑO EN CAÑA DE AZÚCAR A PARTIR DE IMAGENES DIGITALES

# %% [markdown]
# ## Conceptos básicos

# %% [markdown]
# ### * La imagen digital se puede definir como una representación en dos dimensiones de una imagen basada en una matriz numérica binaria.
# ### * Existen muchos tipos de imágenes digitales, las mas usadas son:
# ####          + Vectorial: Basada en vectores, polígonos, curvas
# ####          + Mapa de bits: distribución de puntos de color o pixeles a manera de mapa
# ####          + JPEG: es el formato más conocido del mapa de bits, pierde calidad al guardarse
# ####          + TIFF: Formato de archivo de imagen etiquetado, más pesado que JPEG
# ####          + GIF: Formato de gráficos intercambiable, soporta animación y solo 256 colores.
# ####          + RAW: conocido como formato bruto, ya que es el archivo original.

# %% [markdown]
# ## Procesamiento de la imagen

# %% [markdown]
# El enfoque multiclase de Naive Bayes es una extensión del enfoque de Naive Bayes. Se puede entrenar para generar imágenes binarias dada una imagen de color de entrada. El enfoque multiclase Bayes puede entrenarse para clasificar dos o más clases, definidas por el usuario. Además, se entrena utilizando colores escasamente muestreados de imágenes en lugar de la necesidad de etiquetar todos los píxeles en una imagen determinada.
#
# Para entrenar el clasificador, necesitamos construir una tabla de valores de color rojo, verde y azul para píxeles muestreados uniformemente de cada clase. La idea aquí es recopilar una muestra relevante de datos de color de píxeles para cada clase. El tamaño de la muestra necesaria para construir funciones de densidad de probabilidad robustas para cada clase dependerá de una serie de factores, incluida la variabilidad en los colores de la clase y la calidad/reproducibilidad de la imagen.
#
# Para recopilar datos de color de píxeles, actualmente usamos la herramienta de inspección de píxeles en ImageJ. Utilice la herramienta de inspección de píxeles para seleccionar regiones de la imagen que pertenezcan a una sola clase. Al hacer clic en un píxel de la imagen, obtendrá un conjunto de valores R, G, B para una ventana de píxeles alrededor del píxel central. En este ejemplo, se muestrean nueve píxeles con un solo clic, pero el radio se puede ajustar en "Preferencias".
#
# Cada columna de la tabla delimitada por tabuladores es una clase de entidad (en este ejemplo, planta, pústula, clorosis o fondo) y cada celda es un triplete rojo, verde y azul separado por comas para un píxel.
#
# Desde la ventana "Valores de píxeles" puede copiar los valores y pegarlos en un editor de texto como Notepad en Windows, TextEditor en MacOS, Atom o VS Code. Los valores R,G,B para una clase deben ir precedidos de una línea que contenga el nombre de la clase precedido por un
#
# Los datos obtenidos de la matriz de pixeles se colocan en un block de notas colocando el encabezado de cada clasificación y se guarda el archivo en formato texto.
#
# #. El contenido del archivo debería verse así:
#
# #planta 93,166,104 94,150,101 82,137,91 86,154,102 87,145,94 79,137,95 116,185,135 103,172,126 96,166,126 #pustula 216,130,52 217,129,51 221,132,53 218,131,53 223,132,54 221,132,53 219,131,54 221,132,54 225,135,56 #clorosis 255,242,89 255,241,90 255,239,87 254,239,87 255,241,90 254,238,88 255,241,88 253,238,87 255,240,90 #fondo 31,42,54 42,52,60 40,49,58 28,38,51 32,43,55 36,47,59 24,35,45 30,40,50 37,49,66
#
# El archivo requiere ser acomodado considerando el encabezado de las clases, se consideran las capas de color RGB separadas por una coma y entre columnas por una tabulación. Para lo cual se realiza un script considerando un clasificador bayesiano

# %%
#!/usr/bin/env python

import sys
import argparse
import plantcv.utils


# Parse command-line arguments
###########################################
def options():
    """Parse command line options.
    """
    # Create an argument parser
    parser = argparse.ArgumentParser(description="A collection of utilities for PlantCV.",
                                     formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    # Create subcommand parsers
    subparsers = parser.add_subparsers()

   # Create the tabulate_bayes_classes subcommand
    json2csv_cmd = subparsers.add_parser("tabulate_bayes_classes", help="Convert pixel samples to a Bayes class table.")
    json2csv_cmd.add_argument("-i", "./muestras.txt", help="Input text file.", required=True)
    json2csv_cmd.add_argument("-o", "./res-pdfs.txt", help="Output tab-delimited table file.", required=True)
    json2csv_cmd.set_defaults(func=run_tabulate_bayes_classes)

#    plantcv-utils.py tabulate_bayes_classes -i ./muestras.txt -o ./res-pdfs.txt
    
    
     # If no arguments are given, print the help menu
    if len(sys.argv) == 1:
        parser.print_help(sys.stderr)
        raise SystemExit()

    # Parse command-line options
    args = parser.parse_args()
    # Execute the selected method
    args.func(args)

###########################################


# Run the naive Bayes tabulation converter
###########################################
def run_tabulate_bayes_classes(args):
    plantcv.utils.tabulate_bayes_classes(input_file=args.infile, output_file=args.outfile)
###########################################

# %%
plantcv.utils.tabulate_bayes_classes("C:/Users/semex/Desktop/TRABAJO_FINAL_COA501/MASCARAS/muestras.txt", "C:/Users/semex/Desktop/TRABAJO_FINAL_COA501/MASCARAS/res-pdfs.txt")

# %% [markdown]
# A continuación, cada clase debe estar en su propia columna para plantcv-train. Puede usar un script de utilidad provisto con PlantCV en plantcv-utils.py que convertirá los datos del Inspector de píxeles en una tabla para el algoritmo de entrenamiento bayesiano.
#
# python plantcv-utils.py tabulate_bayes_classes -i pixel_inspector_rgb_values.txt -o bayes_classes.tsv
#
# Una nota si está utilizando Windows, deberá especificar la ruta completa a plantcv-utils.py.
#
# El archivo con los valores de píxel que creó anteriormente y bayes_classes.tsv es el archivo con la tabla para plantcv-train.py. Una tabla de ejemplo construida a partir de muestras de píxeles para usar en plantcv-train.py se ve así:
#
# ###### daño	planta	fondo
# ###### 135,103,178	132,118,0	50,138,152
# ###### 134,102,177	131,116,0	48,136,150
# ###### 135,101,177	132,116,3	49,137,151
# ###### 139,100,179	132,116,5	48,137,151
#
# # Nota: las columnas están separadas por tabulaciones, así mismo los datos se guardan como archivo txt.
#
# Para entrenamiento utilizaremos un multiclasificador Bayesiano. El archivo que se genera partiendo de información o imágenes RGB de 8 bits, con las que se generan las mascaras binarias de entrada. Las imágenes de color de  entrada se convierten en el espacio de color HSV.

# %%
# Naive Bayes

import os
import cv2
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt


def naive_bayes(imgdir, maskdir, outfile, mkplots=False):
    """Naive Bayes training function
    Inputs:
    imgdir  = Path to a directory of original 8-bit RGB images.
    maskdir = Path to a directory of binary mask images. Mask images must have the same name as their corresponding
              color images.
    outfile = Name of the output text file that will store the color channel probability density functions.
    mkplots = Make PDF plots (True or False).
    :param imgdir: str
    :param maskdir: str
    :param outfile: str
    :param mkplots: bool
    """
    # Initialize color channel ndarrays for plant (foreground) and background
    plant = {"hue": np.array([], dtype=np.uint8), "saturation": np.array([], dtype=np.uint8),
             "value": np.array([], dtype=np.uint8)}
    background = {"hue": np.array([], dtype=np.uint8), "saturation": np.array([], dtype=np.uint8),
                  "value": np.array([], dtype=np.uint8)}

    # Walk through the image directory
    print("Reading images...")
    for (dirpath, dirnames, filenames) in os.walk(imgdir):
        for filename in filenames:
            # Is this an image type we can work with?
            if filename[-3:] in ['png', 'jpg', 'jpeg']:
                # Does the mask exist?
                if os.path.exists(os.path.join(maskdir, filename)):
                    # Read the image as BGR
                    img = cv2.imread(os.path.join(dirpath, filename), 1)
                    # Read the mask as grayscale
                    mask = cv2.imread(os.path.join(maskdir, filename), 0)

                    # Convert the image to HSV and split into component channels
                    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
                    hue, saturation, value = cv2.split(hsv)

                    # Store channels in a dictionary
                    channels = {"hue": hue, "saturation": saturation, "value": value}

                    # Split channels into plant and non-plant signal
                    for channel in channels:
                        fg, bg = _split_plant_background_signal(channels[channel], mask)

                        # Randomly sample from the plant class (sample 10% of the pixels)
                        fg = fg[np.random.randint(0, len(fg) - 1, int(len(fg) / 10))]
                        # Randomly sample from the background class the same n as the plant class
                        bg = bg[np.random.randint(0, len(bg) - 1, len(fg))]
                        plant[channel] = np.append(plant[channel], fg)
                        background[channel] = np.append(background[channel], bg)

    # Calculate a probability density function for each channel using a Gaussian kernel density estimator
    # Create an output file for the PDFs
    with open(outfile, "w") as out:
        out.write("class\tchannel\t" + "\t".join(map(str, range(0, 256))) + "\n")
        for channel in plant:
            print("Calculating PDF for the " + channel + " channel...")
            plant_kde = stats.gaussian_kde(plant[channel])
            bg_kde = stats.gaussian_kde(background[channel])
            # Calculate p from the PDFs for each 8-bit intensity value and save to outfile
            plant_pdf = plant_kde(range(0, 256))
            out.write("plant\t" + channel + "\t" + "\t".join(map(str, plant_pdf)) + "\n")
            bg_pdf = bg_kde(range(0, 256))
            out.write("background\t" + channel + "\t" + "\t".join(map(str, bg_pdf)) + "\n")
            if mkplots:
                # If mkplots is True, make the PDF charts
                _plot_pdf(channel, os.path.dirname(outfile), plant=plant_pdf, background=bg_pdf)


def naive_bayes_multiclass(samples_file, outfile, mkplots=False):
    """Naive Bayes training function for two or more classes from sampled pixel RGB values.
    Inputs:
    samples_file = Input text file containing sampled pixel RGB values for each training class. The file should be a
                   tab-delimited table with one training class per column. The required first row must contain header
                   labels for each class. The row values for each class must be comma-delimited RGB values.
                   You must have at least 2 classes. See the file plantcv/tests/data/sampled_rgb_points.txt for
                   an example.
    outfile      = Name of the output text file that will store the color channel probability density functions.
    mkplots      = Make PDF plots (True or False).
    :param samples_file: str
    :param outfile: str
    :param mkplots: bool
    """
    # Initialize a dictionary to store sampled RGB pixel values for each input class
    sample_points = {}
    # Open the sampled points text file
    with open(samples_file, "r") as f:
        # Read the first line and use the column headers as class labels
        header = f.readline()
        header = header.rstrip("\n")
        class_list = header.split("\t")
        # Initialize a dictionary for the red, green, and blue channels for each class
        for cls in class_list:
            sample_points[cls] = {"red": [], "green": [], "blue": []}
        # Loop over the rest of the data in the input file
        for row in f:
            # Remove newlines and quotes
            row = row.rstrip("\n")
            row = row.replace('"', '')
            # If this is not a blank line, parse the data
            if len(row) > 0:
                # Split the row into a list of points per class
                points = row.split("\t")
                # For each point per class
                for i, point in enumerate(points):
                    if len(point) > 0:
                        # Split the point into red, green, and blue integer values
                        red, green, blue = map(int, point.split(","))
                        # Append each intensity value into the appropriate class list
                        sample_points[class_list[i]]["red"].append(red)
                        sample_points[class_list[i]]["green"].append(green)
                        sample_points[class_list[i]]["blue"].append(blue)

    # Initialize a dictionary to store probability density functions per color channel in HSV colorspace
    pdfs = {"hue": {}, "saturation": {}, "value": {}}
    # For each class
    for cls in class_list:
        # Create a blue, green, red-formatted image ndarray with the class RGB values
        bgr_img = cv2.merge((np.asarray(sample_points[cls]["blue"], dtype=np.uint8),
                             np.asarray(sample_points[cls]["green"], dtype=np.uint8),
                             np.asarray(sample_points[cls]["red"], dtype=np.uint8)))
        # Convert the BGR ndarray to an HSV ndarray
        hsv_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2HSV)
        # Split the HSV ndarray into the component HSV channels
        hue, saturation, value = cv2.split(hsv_img)
        # Create an HSV channel dictionary that stores the channels as lists (horizontally stacked ndarrays)
        channels = {"hue": np.hstack(hue), "saturation": np.hstack(saturation), "value": np.hstack(value)}
        # For each channel
        for channel in channels:
            # Create a kernel density estimator for the channel values (Gaussian kernel)
            kde = stats.gaussian_kde(channels[channel])
            # Use the KDE to calculate a probability density function for the channel
            # Sample at each of the possible 8-bit values
            pdfs[channel][cls] = kde(range(0, 256))
    if mkplots:
        # If mkplots is True, generate a density curve plot per channel for each class
        for channel, cls in pdfs.items():
            _plot_pdf(channel, os.path.dirname(outfile), **cls)
    # Write the PDFs to a text file
    out = open(outfile, "w")
    # Write the column labels
    out.write("class\tchannel\t" + "\t".join(map(str, range(0, 256))) + "\n")
    # For each channel
    for channel, cls in pdfs.items():
        # For each class
        for class_name, pdf in cls.items():
            # Each row is the PDF for the given class and color channel
            out.write(class_name + "\t" + channel + "\t" + "\t".join(map(str, pdf)) + "\n")


def _split_plant_background_signal(channel, mask):
    """Split a single-channel image by foreground and background using a mask
    :param channel: ndarray
    :param mask: ndarray
    :return plant: ndarray
    :return background: ndarray
    """
    plant = channel[np.where(mask == 255)]
    background = channel[np.where(mask == 0)]

    return plant, background


def _plot_pdf(channel, outdir, **kwargs):
    """Plot the probability density function of one or more classes for the given channel
    :param channel: str
    :param outdir: str
    :param kwargs: dict
    """
    for class_name, pdf in kwargs.items():
        plt.plot(pdf, label=class_name)
    plt.legend(loc="best")
    plt.savefig(os.path.join(outdir, str(channel) + "_pdf.svg"))
    plt.close()

# %%
naive_bayes_multiclass("C:/Users/semex/Desktop/TRABAJO_FINAL_COA501/MASCARAS/res-pdfs.txt", "C:/Users/semex/Desktop/TRABAJO_FINAL_COA501/MASCARAS/resulted-multiclass-pdfs.txt" , mkplots=False)

# %% [markdown]
# Una vez que se recopila una muestra satisfactoria de píxeles, guarde la tabla como un archivo de texto delimitado por tabulaciones. Use plantcv-train.py para usar las muestras de píxeles para generar funciones de densidad de probabilidad (PDF) para cada clase.
#
# plantcv-train.py naive_bayes_multiclass --file pixel_samples.txt --outfile naive_bayes_pdfs.txt --plots
#
# El archivo de salida de plantcv-train.py contendrá una fila para cada canal de color (tono, saturación y valor) para cada clase. La primera y segunda columna son la etiqueta de clase y canal, respectivamente. Las 256 columnas restantes contienen el valor p de las PDF para cada valor de intensidad observable en una imagen de 8 bits (0-255).
#
# Una vez que tenemos el archivo de salida plantcv-train.py, podemos clasificar los píxeles en una imagen en color en PlantCV. En la imagen de ejemplo de este tutorial, ya hemos recopilado píxeles y creado las funciones de densidad de probabilidad para cada clase.
#
# plantcv-train.py naive_bayes_multiclass --file pixel_samples.txt --outfile naive_bayes_pdfs.txt --plots
#
# Quedando el archivo, con la siguiente confioguración:
#
# ###### class	channel	0	1	2	3
# ###### fondo	hue	0.0009795631932763345	0.00097861026497977	0.0009719698493849301
# ###### planta	hue	5.807149706258918e-32	1.031519015692794e-30	1.7195081605849894e-29
# ###### flor	hue	5.5119358591664e-37	1.352894755248708e-31	1.1285875760814367e-26
# ###### fondo	saturation	0.0033856814809592062	0.003591994941836821	0.0038007934381232107
# ###### planta	saturation	4.497453085379968e-08	6.443690840084825e-08	9.165244985285992e-08
# ###### flor	saturation	1.6945940767175099e-43	6.645042174936202e-43	2.5786996575232306e-42
# ###### fondo	value	3.941696882818343e-05	4.8884252661236044e-05	6.035641398983069e-05
# ###### planta	value	7.586300316264174e-08	1.0257491976670049e-07	1.38058414598911e-07
# ###### flor	value	1.2054220475261588e-69	1.127171004858784e-68	1.036535189299834e-67

# %% [markdown]
# # Importar librerias

# %%
import cv2
import numpy as np
from plantcv import plantcv as pcv
import pandas as pd

#Librería para contar número de objetos (Cálculo del número de Euler)
import mahotas

# Establecer el comportamiento de depuración global en Ninguno (default), "imprimir" (en archivo)

pcv.params.debug = "print"


image="C:/Users/semex/Desktop/TRABAJO_FINAL_COA501/MASCARAS/img/196.jpg"
pdfs="./resulted-multiclass-pdfs.txt"
results="./resulted-multiclas.json"

# %%
class options:
    def __init__(self):
        self.image = image
        self.debug = "plot"
        self.writeimg= False 
        self.result = results
        self.outdir = "."

# Get options
args = options()

# Set debug to the global parameter 
pcv.params.debug = args.debug

# %% [markdown]
# Leer en una imagen a color
#
# # Entradas:
#
# filename - Archivo de imagen para leer
# mode - Modo de retorno de la imagen; ya sea 'nativo' (predeterminado), 'rgb', 'gris' o 'csv'

# %%
img, path, filename = pcv.readimage(filename=args.image)

# %% [markdown]
# Read in a color image
#
# img, path, filename = pcv.readimage("color_image.png")

# %%
gaussian_img = pcv.gaussian_blur(img=img, ksize=(5, 5), sigma_x=1, sigma_y=1)

# %% [markdown]
# Use el archivo de salida de `plantcv-train.py` para ejecutar la multiclase
#
# clasificación bayesiana ingenua en la imagen. La siguiente función será
#
# imprime 4 máscaras (lección, prelección, verde, fondo)
#
# # Entradas:
#
# rgb_img - Datos de imagen RGB
# pdf_file - Archivo de salida que contiene archivos PDF de `plantcv-train.py`

# %%
mask = pcv.naive_bayes_classifier(rgb_img=gaussian_img, 
                                  pdf_file=pdfs)

# %%
clorosis_img=pcv.fill_holes(bin_img=mask['clorosis'])

# %%
clorosis_fill=pcv.fill(bin_img=clorosis_img, size=200)

# %%
planta_img=pcv.fill_holes(bin_img=mask['planta'])

# %%
planta_fill=pcv.fill(bin_img=planta_img, size=200)

# %%
mask['clorosis']=clorosis_fill
mask['planta']=planta_fill

# %% [markdown]
# Podemos aplicar cada máscara a la imagen original con mayor precisión, ver lo que se enmascaró
#
# # Entradas:
# img - Datos de imagen RGB o en escala de grises
# mask - Datos de imagen de máscara binaria
# mask_color - 'blanco' o 'negro'

# %%
clorosis_img = pcv.apply_mask(mask=(mask['clorosis']), img=img, mask_color='white')
planta_img = pcv.apply_mask(mask=(mask['planta']), img=img, mask_color='black')
fondo_img = pcv.apply_mask(mask=(mask['fondo']), img=img, mask_color='black')

# %% [markdown]
# #Escribir imagen y máscara con el mismo nombre en la ruta especificado (crea dos carpetas dentro de la ruta si no existen).
#
# # Entradas:
#
# img - Datos de imagen RGB o en escala de grises, imagen original
# mask - Imagen de máscara binaria creada
# filename - Nombre de archivo de imagen para guardar como
# outdir - Directorio de salida (predeterminado: Ninguno)
# mask_only: el valor predeterminado es falso, si es verdadero, solo genera una máscara

# %%
lesson_maskpath, plant_analysis_images = pcv.output_mask(img=img, mask=mask['clorosis'], 
                                                        filename='clorosis.png', mask_only=True)
green_maskpath, chlor_analysis_images = pcv.output_mask(img=img, mask=mask['planta'], 
                                                        filename='planta.png', mask_only=True)
bkgrd_maskpath, bkgrd_analysis_images = pcv.output_mask(img=img, mask=mask['fondo'], 
                                                        filename='fondo.png', mask_only=True)

# %% [markdown]
# Para ver todas estas máscaras juntas, podemos trazarlas con la planta configurada en verde,
#
# clorosis de color dorado y pústula de color rojo.
#
# # Entradas:
# masks - Lista de máscaras (las diferentes clases devueltas por naive_bayes_classifier)
# colores - Lista de colores para asignar a cada clase. Los usuarios pueden proporcionar un
# lista de nombres de colores (str) o puede proporcionar tuplas de valores BGR personalizados

# %%
classified_img = pcv.visualize.colorize_masks(masks=[mask['clorosis'], 
                                                     mask['planta'], mask['fondo']], 
                                              colors=['red', 'green', 'black'])

# %% [markdown]
# # Calcular el porcentaje de la planta que se encuentra enferma

# %%
planta_total = np.count_nonzero(mask['planta']) + np.count_nonzero(mask['clorosis'])
planta = np.count_nonzero(mask['planta'])
clorosis= np.count_nonzero(mask['clorosis'])
                                  
porciento_clorosis = clorosis*100 / (planta_total)
porciento_planta = planta*100 / (planta_total)
porciento_planta_total = planta_total*100 / (img.shape[0]*img.shape[1])

print('Superficie de clorosis (%):','{:.1f}'.format(porciento_clorosis))
print('Superficie de planta (%):','{:.1f}'.format(porciento_planta))
print('Superficie de la planta en la imagen (%):', '{:,.1f}'.format(porciento_planta_total))
# Out:
# Superficie de clorosis (%): 26.9
# Superficie de planta (%): 73.1
# Superficie de la planta en la imagen (%): 16.6
